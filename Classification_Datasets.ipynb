# %%
# Jupyter Notebook Code to List Datasets with Links and Documentation

from IPython.display import Markdown, display

def print_dataset_info(name, link, description):
    display(Markdown(f"### [{name}]({link})"))
    display(Markdown(f"{description}\n"))

datasets = [
    {
        'name': 'Breast Cancer Wisconsin Dataset',
        'link': 'https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic)',
        'description': 'Predict whether a tumor is malignant or benign based on features of cell nuclei present in the image.'
    },
    {
        'name': 'Wine Quality Dataset',
        'link': 'https://archive.ics.uci.edu/ml/datasets/Wine+Quality',
        'description': 'Predict the quality of wine based on physicochemical tests of various wine samples.'
    },
    {
        'name': 'Iris Dataset',
        'link': 'https://archive.ics.uci.edu/ml/datasets/iris',
        'description': 'Classify iris flowers into three species (Setosa, Versicolor, Virginica) based on sepal and petal dimensions.'
    },
    {
        'name': 'Titanic Dataset',
        'link': 'https://www.kaggle.com/c/titanic',
        'description': 'Predict survival on the Titanic based on features such as age, class, and gender.'
    },
    {
        'name': 'MNIST Handwritten Digits',
        'link': 'https://www.kaggle.com/c/digit-recognizer',
        'description': 'Classify handwritten digits (0-9) using pixel values from images.'
    },
    {
        'name': 'Pima Indians Diabetes Dataset',
        'link': 'https://www.kaggle.com/uciml/pima-indians-diabetes-database',
        'description': 'Predict whether a patient has diabetes based on diagnostic measurements.'
    },
    {
        'name': 'Fashion MNIST',
        'link': 'https://www.kaggle.com/zalando-research/fashionmnist',
        'description': 'Classify clothing images into different categories such as T-shirts, shoes, and bags.'
    },
    {
        'name': 'Heart Disease Dataset',
        'link': 'https://archive.ics.uci.edu/ml/datasets/heart+disease',
        'description': 'Predict the presence of heart disease based on various medical and diagnostic measurements.'
    },
    {
        'name': 'Credit Card Fraud Detection',
        'link': 'https://www.kaggle.com/mlg-ulb/creditcardfraud',
        'description': 'Detect fraudulent credit card transactions from a dataset of real-world financial transactions.'
    },
    {
        'name': 'Banknote Authentication Dataset',
        'link': 'https://archive.ics.uci.edu/ml/datasets/banknote+authentication',
        'description': 'Classify banknotes as genuine or forged based on image features such as wavelet transforms.'
    }
]

for dataset in datasets:
    print_dataset_info(dataset['name'], dataset['link'], dataset['description'])
# Out:
# ### [Breast Cancer Wisconsin Dataset](https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic))
# Predict whether a tumor is malignant or benign based on features of cell nuclei present in the image.
# ### [Wine Quality Dataset](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)
# Predict the quality of wine based on physicochemical tests of various wine samples.
# ### [Iris Dataset](https://archive.ics.uci.edu/ml/datasets/iris)
# Classify iris flowers into three species (Setosa, Versicolor, Virginica) based on sepal and petal dimensions.
# ### [Titanic Dataset](https://www.kaggle.com/c/titanic)
# Predict survival on the Titanic based on features such as age, class, and gender.
# ### [MNIST Handwritten Digits](https://www.kaggle.com/c/digit-recognizer)
# Classify handwritten digits (0-9) using pixel values from images.
# ### [Pima Indians Diabetes Dataset](https://www.kaggle.com/uciml/pima-indians-diabetes-database)
# ...
